# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks

# %%
# 1. 데이터 로딩: RoBERTa만 사용
def load_data(path):
    df = pd.read_json(path)
    roberta = np.array(df['roberta_cls'].tolist())
    y = df['fake'].values
    return roberta, y

# %%
# 2. 모델 정의: RoBERTa만 사용
def build_model():
    roberta_input = layers.Input(shape=(768,))

    x = layers.Dense(256, activation='relu')(roberta_input)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=roberta_input, outputs=output)
    model.compile(optimizer=optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# 3. 학습 함수 수정: 입력 하나만
def train_model(X, y):
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42)

    model = build_model()

    early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=64,
        callbacks=[early_stop]
    )

    y_pred_prob = model.predict(X_val)
    y_pred = (y_pred_prob > 0.5).astype(int)

    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred)
    rec = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1 Score : {f1:.4f}")

    return model

# %%
X, y = load_data("emb_cls.json")
model = train_model(X, y)
# Out:
# Epoch 1/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6250 - loss: 0.6377 - val_accuracy: 0.7119 - val_loss: 0.5586
# Epoch 2/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7133 - loss: 0.5619 - val_accuracy: 0.7194 - val_loss: 0.5485
# Epoch 3/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7178 - loss: 0.5536 - val_accuracy: 0.7206 - val_loss: 0.5435
# Epoch 4/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7252 - loss: 0.5438 - val_accuracy: 0.7230 - val_loss: 0.5404
# Epoch 5/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7294 - loss: 0.5371 - val_accuracy: 0.7274 - val_loss: 0.5357
# Epoch 6/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7295 - loss: 0.5351 - val_accuracy: 0.7294 - val_loss: 0.5335
# Epoch 7/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7261 - loss: 0.5382 - val_accuracy: 0.7286 - val_loss: 0.5328
# Epoch 8/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7315 - loss: 0.5320 - val_accuracy: 0.7325 - val_loss: 0.5295
# Epoch 9/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7307 - loss: 0.5295 - val_accuracy: 0.7309 - val_loss: 0.5288
# Epoch 10/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7307 - loss: 0.5291 - val_accuracy: 0.7327 - val_loss: 0.5265
# Epoch 11/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7355 - loss: 0.5273 - val_accuracy: 0.7318 - val_loss: 0.5262
# Epoch 12/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7318 - loss: 0.5253 - val_accuracy: 0.7340 - val_loss: 0.5256
# Epoch 13/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7351 - loss: 0.5236 - val_accuracy: 0.7313 - val_loss: 0.5259
# Epoch 14/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7357 - loss: 0.5253 - val_accuracy: 0.7335 - val_loss: 0.5242
# Epoch 15/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7363 - loss: 0.5241 - val_accuracy: 0.7346 - val_loss: 0.5229
# Epoch 16/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7375 - loss: 0.5218 - val_accuracy: 0.7354 - val_loss: 0.5217
# Epoch 17/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7407 - loss: 0.5163 - val_accuracy: 0.7351 - val_loss: 0.5223
# Epoch 18/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7404 - loss: 0.5186 - val_accuracy: 0.7339 - val_loss: 0.5235
# Epoch 19/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7391 - loss: 0.5198 - val_accuracy: 0.7343 - val_loss: 0.5203
# Epoch 20/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7421 - loss: 0.5191 - val_accuracy: 0.7356 - val_loss: 0.5224
# Epoch 21/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7410 - loss: 0.5158 - val_accuracy: 0.7317 - val_loss: 0.5247
# Epoch 22/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7412 - loss: 0.5165 - val_accuracy: 0.7347 - val_loss: 0.5198
# Epoch 23/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7446 - loss: 0.5115 - val_accuracy: 0.7344 - val_loss: 0.5193
# Epoch 24/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7449 - loss: 0.5120 - val_accuracy: 0.7338 - val_loss: 0.5211
# Epoch 25/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7453 - loss: 0.5118 - val_accuracy: 0.7376 - val_loss: 0.5184
# Epoch 26/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7468 - loss: 0.5094 - val_accuracy: 0.7381 - val_loss: 0.5194
# Epoch 27/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7426 - loss: 0.5116 - val_accuracy: 0.7362 - val_loss: 0.5209
# Epoch 28/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7479 - loss: 0.5088 - val_accuracy: 0.7384 - val_loss: 0.5191
# Epoch 29/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7449 - loss: 0.5079 - val_accuracy: 0.7373 - val_loss: 0.5181
# Epoch 30/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7463 - loss: 0.5102 - val_accuracy: 0.7389 - val_loss: 0.5178
# Epoch 31/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7491 - loss: 0.5057 - val_accuracy: 0.7370 - val_loss: 0.5205
# Epoch 32/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7489 - loss: 0.5055 - val_accuracy: 0.7355 - val_loss: 0.5202
# Epoch 33/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7500 - loss: 0.5047 - val_accuracy: 0.7378 - val_loss: 0.5174
# Epoch 34/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7503 - loss: 0.5048 - val_accuracy: 0.7400 - val_loss: 0.5169
# Epoch 35/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7533 - loss: 0.5021 - val_accuracy: 0.7368 - val_loss: 0.5184
# Epoch 36/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7512 - loss: 0.5040 - val_accuracy: 0.7400 - val_loss: 0.5175
# Epoch 37/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7535 - loss: 0.5026 - val_accuracy: 0.7374 - val_loss: 0.5161
# Epoch 38/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7498 - loss: 0.5037 - val_accuracy: 0.7399 - val_loss: 0.5161
# Epoch 39/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7493 - loss: 0.5017 - val_accuracy: 0.7406 - val_loss: 0.5171
# Epoch 40/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7523 - loss: 0.5009 - val_accuracy: 0.7401 - val_loss: 0.5182
# Epoch 41/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7549 - loss: 0.4997 - val_accuracy: 0.7374 - val_loss: 0.5171
# Epoch 42/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7538 - loss: 0.4985 - val_accuracy: 0.7398 - val_loss: 0.5161
# Epoch 43/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7546 - loss: 0.4977 - val_accuracy: 0.7374 - val_loss: 0.5186
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step
# Accuracy : 0.7399
# Precision: 0.7357
# Recall   : 0.7490
# F1 Score : 0.7423
